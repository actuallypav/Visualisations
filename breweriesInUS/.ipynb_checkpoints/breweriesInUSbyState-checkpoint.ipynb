# %%
import folium
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\actua\\Desktop\\DataSets\\breweries\\breweries_us.csv')
df = df.rename(columns={"state_breweries":"count"})
df['count'] = 1

# %%
df
# Out:
#                                      brewery_name             type  \
# 0                              Valley Brewing Co.          Brewpub
# 1                              Valley Brewing Co.          Brewpub
# 2                               Valley Brewing Co     Microbrewery
# 3                           Ukiah Brewing Company          Brewpub
# 4                              Tustin Brewing Co.          Brewpub
# ...                                           ...              ...
# 2402  Capitol City Brewing Company (Capitol Hill)          Brewpub
# 2403                 Capitol City Brewing Company          Brewpub
# 2404                           Old Harbor Brewery          Brewpub
# 2405                       Isla Verde Brewing Co.     Microbrewery
# 2406                         Cerveceria India Inc  RegionalBrewery
#
#                                                 address  \
# 0              PO Box 4653, Stockton, California, 95204
# 1            157 Adams St., Stockton, California, 95204
# 2          1950 W Freemont, Stockton, California, 95203
# 3            102 S. State St., Ukiah, California, 95482
# 4     13011 Newport Ave. #100, Tustin, California, 9...
# ...                                                 ...
# 2402  2 Massachusetts Ave., Washington, DC, Washingt...
# 2403  1100 New York Ave. NW, Washington, DC, Washing...
# 2404  Gen del Valle 1021 Urb Delicias, San Juan, PR,...
# 2405  Condiminum Torrimar Plaza # 14B, Guaynabo , PR...
# 2406                     PO Box 1690, Mayaguez, PR, 681
#
#                                                 website                 state  \
# 0                            http://www.valleybrew.com/            California
# 1                            http://www.valleybrew.com/            California
# 2                            http://www.valleybrew.com/            California
# 3                        http://www.ukiahbrewingco.com/            California
# 4                         http://www.tustinbrewery.com/            California
# ...                                                 ...                   ...
# 2402                        http://www.capcitybrew.com/  District of Columbia
# 2403                        http://www.capcitybrew.com/  District of Columbia
# 2404                       http://oldharborbrewery.com/           Puerto Rico
# 2405                                                ...           Puerto Rico
# 2406                                                ...           Puerto Rico
#
#       count
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 2402      1
# 2403      1
# 2404      1
# 2405      1
# 2406      1
#
# [2407 rows x 6 columns]

# %%
amountOfBreweries = df.groupby('state',as_index=False,sort=False).sum()
amountOfBreweries
# Out:
#                    state  count
# 0             California    284
# 1                 Nevada     18
# 2                Wyoming      8
# 3                Alabama      6
# 4            Connecticut     11
# 5                   Iowa     13
# 6               Missouri     21
# 7               Nebraska     15
# 8                 Alaska     14
# 9                Arizona     34
# 10              Arkansas      7
# 11              Colorado    182
# 12              Delaware     14
# 13               Florida     99
# 14               Georgia     47
# 15                Hawaii     10
# 16                 Idaho     28
# 17              Illinois     74
# 18               Indiana     31
# 19                Kansas     26
# 20              Kentucky     12
# 21             Louisiana     15
# 22                 Maine     44
# 23              Maryland     43
# 24         Massachusetts     71
# 25              Michigan     94
# 26             Minnesota     40
# 27               Montana     32
# 28         New Hampshire     18
# 29            New Jersey     41
# 30            New Mexico     37
# 31              New York    107
# 32        North Carolina     61
# 33          North Dakota      5
# 34                  Ohio     56
# 35              Oklahoma     16
# 36                Oregon    156
# 37          Pennsylvania    107
# 38          Rhode Island     12
# 39        South Carolina     32
# 40          South Dakota     11
# 41             Tennessee     28
# 42                 Texas     90
# 43                  Utah     21
# 44               Vermont     28
# 45              Virginia     43
# 46            Washington    151
# 47         West Virginia      5
# 48             Wisconsin     77
# 49  District of Columbia      9
# 50           Puerto Rico      3

# %%
typeOfBrewery = pd.pivot_table(df, values = ['count'], index = ('state','type'), aggfunc=np.sum)
typeOfBrewery = typeOfBrewery.rename(columns={"count":"amount"})
typeOfBrewery
# Out:
#                            amount
# state     type
# Alabama   Brewpub               2
#           Contract              1
#           ContractBrewery       1
#           Microbrewery          2
# Alaska    Brewpub               5
# ...                           ...
# Wisconsin ContractBrewery       2
#           Microbrewery         27
#           RegionalBrewery       4
# Wyoming   Brewpub               6
#           Microbrewery          2
#
# [234 rows x 1 columns]

# %%
geoUS = gpd.read_file("C:\\Users\\actua\\Desktop\\geos\\us-states.geojson")
geoUS = geoUS.drop(geoUS.index[[24]])
geoUS = geoUS.rename(columns={"name":"state"})
geoUS
# Out:
#     id                 state    density  \
# 0   01               Alabama     94.650
# 1   02                Alaska      1.264
# 2   04               Arizona     57.050
# 3   05              Arkansas     56.430
# 4   06            California    241.700
# 5   08              Colorado     49.330
# 6   09           Connecticut    739.100
# 7   10              Delaware    464.300
# 8   11  District of Columbia  10065.000
# 9   12               Florida    353.400
# 10  13               Georgia    169.500
# 11  15                Hawaii    214.100
# 12  16                 Idaho     19.150
# 13  17              Illinois    231.500
# 14  18               Indiana    181.700
# 15  19                  Iowa     54.810
# 16  20                Kansas     35.090
# 17  21              Kentucky    110.000
# 18  22             Louisiana    105.000
# 19  23                 Maine     43.040
# 20  24              Maryland    596.300
# 21  25         Massachusetts    840.200
# 22  26              Michigan    173.900
# 23  27             Minnesota     67.140
# 25  29              Missouri     87.260
# 26  30               Montana      6.858
# 27  31              Nebraska     23.970
# 28  32                Nevada     24.800
# 29  33         New Hampshire    147.000
# 30  34            New Jersey   1189.000
# 31  35            New Mexico     17.160
# 32  36              New York    412.300
# 33  37        North Carolina    198.200
# 34  38          North Dakota      9.916
# 35  39                  Ohio    281.900
# 36  40              Oklahoma     55.220
# 37  41                Oregon     40.330
# 38  42          Pennsylvania    284.300
# 39  44          Rhode Island   1006.000
# 40  45        South Carolina    155.400
# 41  46          South Dakota     98.070
# 42  47             Tennessee     88.080
# 43  48                 Texas     98.070
# 44  49                  Utah     34.300
# 45  50               Vermont     67.730
# 46  51              Virginia    204.500
# 47  53            Washington    102.600
# 48  54         West Virginia     77.060
# 49  55             Wisconsin    105.200
# 50  56               Wyoming      5.851
# 51  72           Puerto Rico   1082.000
#
#                                              geometry
# 0   POLYGON ((-87.359 35.001, -85.607 34.985, -85....
# 1   MULTIPOLYGON (((-131.602 55.118, -131.569 55.2...
# 2   POLYGON ((-109.043 37.000, -109.048 31.332, -1...
# 3   POLYGON ((-94.474 36.502, -90.153 36.496, -90....
# 4   POLYGON ((-123.233 42.006, -122.379 42.012, -1...
# 5   POLYGON ((-107.920 41.004, -105.729 40.998, -1...
# 6   POLYGON ((-73.054 42.039, -71.799 42.023, -71....
# 7   POLYGON ((-75.414 39.804, -75.507 39.684, -75....
# 8   POLYGON ((-77.035 38.994, -76.909 38.895, -77....
# 9   POLYGON ((-85.497 30.998, -85.004 31.003, -84....
# 10  POLYGON ((-83.109 35.001, -83.323 34.788, -83....
# 11  MULTIPOLYGON (((-155.635 18.948, -155.881 19.0...
# 12  POLYGON ((-116.048 49.000, -116.048 47.976, -1...
# 13  POLYGON ((-90.640 42.510, -88.789 42.494, -87....
# 14  POLYGON ((-85.990 41.760, -84.807 41.760, -84....
# 15  POLYGON ((-91.368 43.501, -91.215 43.501, -91....
# 16  POLYGON ((-101.906 40.002, -95.306 40.002, -95...
# 17  POLYGON ((-83.903 38.769, -83.679 38.632, -83....
# 18  POLYGON ((-93.608 33.019, -91.166 33.002, -91....
# 19  POLYGON ((-70.704 43.058, -70.824 43.129, -70....
# 20  MULTIPOLYGON (((-75.995 37.953, -76.017 37.953...
# 21  POLYGON ((-70.918 42.888, -70.819 42.872, -70....
# 22  MULTIPOLYGON (((-83.454 41.732, -84.807 41.694...
# 23  POLYGON ((-92.015 46.705, -92.091 46.749, -92....
# 25  POLYGON ((-91.834 40.610, -91.730 40.615, -91....
# 26  POLYGON ((-104.048 49.000, -104.042 47.861, -1...
# 27  POLYGON ((-103.325 43.003, -101.627 42.998, -9...
# 28  POLYGON ((-117.028 42.001, -114.043 41.995, -1...
# 29  POLYGON ((-71.082 45.303, -71.033 44.657, -70....
# 30  POLYGON ((-74.237 41.141, -73.902 40.998, -74....
# 31  POLYGON ((-107.421 37.000, -106.868 36.995, -1...
# 32  POLYGON ((-73.344 45.013, -73.333 44.805, -73....
# 33  POLYGON ((-80.979 36.562, -80.294 36.546, -79....
# 34  POLYGON ((-97.229 49.000, -97.097 48.683, -97....
# 35  POLYGON ((-80.519 41.979, -80.519 40.637, -80....
# 36  POLYGON ((-100.088 37.000, -94.616 37.000, -94...
# 37  POLYGON ((-123.211 46.174, -123.118 46.185, -1...
# 38  POLYGON ((-79.763 42.253, -79.763 42.001, -75....
# 39  MULTIPOLYGON (((-71.197 41.678, -71.120 41.497...
# 40  POLYGON ((-82.764 35.067, -82.551 35.160, -82....
# 41  POLYGON ((-104.048 45.944, -96.561 45.933, -96...
# 42  POLYGON ((-88.055 36.496, -88.071 36.677, -87....
# 43  POLYGON ((-101.813 36.502, -100.000 36.502, -1...
# 44  POLYGON ((-112.164 41.995, -111.047 42.001, -1...
# 45  POLYGON ((-71.504 45.013, -71.493 44.914, -71....
# 46  MULTIPOLYGON (((-75.398 38.013, -75.244 38.030...
# 47  MULTIPOLYGON (((-117.033 49.000, -117.044 47.7...
# 48  POLYGON ((-80.519 40.637, -80.519 39.722, -79....
# 49  POLYGON ((-90.415 46.568, -90.229 46.508, -90....
# 50  POLYGON ((-109.081 45.002, -105.915 45.002, -1...
# 51  POLYGON ((-66.448 17.984, -66.771 18.006, -66....

# %%
geoShapesUS = geoUS[['state','geometry']]
geoShapesUS
# Out:
#                    state                                           geometry
# 0                Alabama  POLYGON ((-87.359 35.001, -85.607 34.985, -85....
# 1                 Alaska  MULTIPOLYGON (((-131.602 55.118, -131.569 55.2...
# 2                Arizona  POLYGON ((-109.043 37.000, -109.048 31.332, -1...
# 3               Arkansas  POLYGON ((-94.474 36.502, -90.153 36.496, -90....
# 4             California  POLYGON ((-123.233 42.006, -122.379 42.012, -1...
# 5               Colorado  POLYGON ((-107.920 41.004, -105.729 40.998, -1...
# 6            Connecticut  POLYGON ((-73.054 42.039, -71.799 42.023, -71....
# 7               Delaware  POLYGON ((-75.414 39.804, -75.507 39.684, -75....
# 8   District of Columbia  POLYGON ((-77.035 38.994, -76.909 38.895, -77....
# 9                Florida  POLYGON ((-85.497 30.998, -85.004 31.003, -84....
# 10               Georgia  POLYGON ((-83.109 35.001, -83.323 34.788, -83....
# 11                Hawaii  MULTIPOLYGON (((-155.635 18.948, -155.881 19.0...
# 12                 Idaho  POLYGON ((-116.048 49.000, -116.048 47.976, -1...
# 13              Illinois  POLYGON ((-90.640 42.510, -88.789 42.494, -87....
# 14               Indiana  POLYGON ((-85.990 41.760, -84.807 41.760, -84....
# 15                  Iowa  POLYGON ((-91.368 43.501, -91.215 43.501, -91....
# 16                Kansas  POLYGON ((-101.906 40.002, -95.306 40.002, -95...
# 17              Kentucky  POLYGON ((-83.903 38.769, -83.679 38.632, -83....
# 18             Louisiana  POLYGON ((-93.608 33.019, -91.166 33.002, -91....
# 19                 Maine  POLYGON ((-70.704 43.058, -70.824 43.129, -70....
# 20              Maryland  MULTIPOLYGON (((-75.995 37.953, -76.017 37.953...
# 21         Massachusetts  POLYGON ((-70.918 42.888, -70.819 42.872, -70....
# 22              Michigan  MULTIPOLYGON (((-83.454 41.732, -84.807 41.694...
# 23             Minnesota  POLYGON ((-92.015 46.705, -92.091 46.749, -92....
# 25              Missouri  POLYGON ((-91.834 40.610, -91.730 40.615, -91....
# 26               Montana  POLYGON ((-104.048 49.000, -104.042 47.861, -1...
# 27              Nebraska  POLYGON ((-103.325 43.003, -101.627 42.998, -9...
# 28                Nevada  POLYGON ((-117.028 42.001, -114.043 41.995, -1...
# 29         New Hampshire  POLYGON ((-71.082 45.303, -71.033 44.657, -70....
# 30            New Jersey  POLYGON ((-74.237 41.141, -73.902 40.998, -74....
# 31            New Mexico  POLYGON ((-107.421 37.000, -106.868 36.995, -1...
# 32              New York  POLYGON ((-73.344 45.013, -73.333 44.805, -73....
# 33        North Carolina  POLYGON ((-80.979 36.562, -80.294 36.546, -79....
# 34          North Dakota  POLYGON ((-97.229 49.000, -97.097 48.683, -97....
# 35                  Ohio  POLYGON ((-80.519 41.979, -80.519 40.637, -80....
# 36              Oklahoma  POLYGON ((-100.088 37.000, -94.616 37.000, -94...
# 37                Oregon  POLYGON ((-123.211 46.174, -123.118 46.185, -1...
# 38          Pennsylvania  POLYGON ((-79.763 42.253, -79.763 42.001, -75....
# 39          Rhode Island  MULTIPOLYGON (((-71.197 41.678, -71.120 41.497...
# 40        South Carolina  POLYGON ((-82.764 35.067, -82.551 35.160, -82....
# 41          South Dakota  POLYGON ((-104.048 45.944, -96.561 45.933, -96...
# 42             Tennessee  POLYGON ((-88.055 36.496, -88.071 36.677, -87....
# 43                 Texas  POLYGON ((-101.813 36.502, -100.000 36.502, -1...
# 44                  Utah  POLYGON ((-112.164 41.995, -111.047 42.001, -1...
# 45               Vermont  POLYGON ((-71.504 45.013, -71.493 44.914, -71....
# 46              Virginia  MULTIPOLYGON (((-75.398 38.013, -75.244 38.030...
# 47            Washington  MULTIPOLYGON (((-117.033 49.000, -117.044 47.7...
# 48         West Virginia  POLYGON ((-80.519 40.637, -80.519 39.722, -79....
# 49             Wisconsin  POLYGON ((-90.415 46.568, -90.229 46.508, -90....
# 50               Wyoming  POLYGON ((-109.081 45.002, -105.915 45.002, -1...
# 51           Puerto Rico  POLYGON ((-66.448 17.984, -66.771 18.006, -66....

# %%
geoAndAmount = geoShapesUS.merge(amountOfBreweries,on='state')
geoAndAmount
# Out:
#                    state                                           geometry  \
# 0                Alabama  POLYGON ((-87.359 35.001, -85.607 34.985, -85....
# 1                 Alaska  MULTIPOLYGON (((-131.602 55.118, -131.569 55.2...
# 2                Arizona  POLYGON ((-109.043 37.000, -109.048 31.332, -1...
# 3               Arkansas  POLYGON ((-94.474 36.502, -90.153 36.496, -90....
# 4             California  POLYGON ((-123.233 42.006, -122.379 42.012, -1...
# 5               Colorado  POLYGON ((-107.920 41.004, -105.729 40.998, -1...
# 6            Connecticut  POLYGON ((-73.054 42.039, -71.799 42.023, -71....
# 7               Delaware  POLYGON ((-75.414 39.804, -75.507 39.684, -75....
# 8   District of Columbia  POLYGON ((-77.035 38.994, -76.909 38.895, -77....
# 9                Florida  POLYGON ((-85.497 30.998, -85.004 31.003, -84....
# 10               Georgia  POLYGON ((-83.109 35.001, -83.323 34.788, -83....
# 11                Hawaii  MULTIPOLYGON (((-155.635 18.948, -155.881 19.0...
# 12                 Idaho  POLYGON ((-116.048 49.000, -116.048 47.976, -1...
# 13              Illinois  POLYGON ((-90.640 42.510, -88.789 42.494, -87....
# 14               Indiana  POLYGON ((-85.990 41.760, -84.807 41.760, -84....
# 15                  Iowa  POLYGON ((-91.368 43.501, -91.215 43.501, -91....
# 16                Kansas  POLYGON ((-101.906 40.002, -95.306 40.002, -95...
# 17              Kentucky  POLYGON ((-83.903 38.769, -83.679 38.632, -83....
# 18             Louisiana  POLYGON ((-93.608 33.019, -91.166 33.002, -91....
# 19                 Maine  POLYGON ((-70.704 43.058, -70.824 43.129, -70....
# 20              Maryland  MULTIPOLYGON (((-75.995 37.953, -76.017 37.953...
# 21         Massachusetts  POLYGON ((-70.918 42.888, -70.819 42.872, -70....
# 22              Michigan  MULTIPOLYGON (((-83.454 41.732, -84.807 41.694...
# 23             Minnesota  POLYGON ((-92.015 46.705, -92.091 46.749, -92....
# 24              Missouri  POLYGON ((-91.834 40.610, -91.730 40.615, -91....
# 25               Montana  POLYGON ((-104.048 49.000, -104.042 47.861, -1...
# 26              Nebraska  POLYGON ((-103.325 43.003, -101.627 42.998, -9...
# 27                Nevada  POLYGON ((-117.028 42.001, -114.043 41.995, -1...
# 28         New Hampshire  POLYGON ((-71.082 45.303, -71.033 44.657, -70....
# 29            New Jersey  POLYGON ((-74.237 41.141, -73.902 40.998, -74....
# 30            New Mexico  POLYGON ((-107.421 37.000, -106.868 36.995, -1...
# 31              New York  POLYGON ((-73.344 45.013, -73.333 44.805, -73....
# 32        North Carolina  POLYGON ((-80.979 36.562, -80.294 36.546, -79....
# 33          North Dakota  POLYGON ((-97.229 49.000, -97.097 48.683, -97....
# 34                  Ohio  POLYGON ((-80.519 41.979, -80.519 40.637, -80....
# 35              Oklahoma  POLYGON ((-100.088 37.000, -94.616 37.000, -94...
# 36                Oregon  POLYGON ((-123.211 46.174, -123.118 46.185, -1...
# 37          Pennsylvania  POLYGON ((-79.763 42.253, -79.763 42.001, -75....
# 38          Rhode Island  MULTIPOLYGON (((-71.197 41.678, -71.120 41.497...
# 39        South Carolina  POLYGON ((-82.764 35.067, -82.551 35.160, -82....
# 40          South Dakota  POLYGON ((-104.048 45.944, -96.561 45.933, -96...
# 41             Tennessee  POLYGON ((-88.055 36.496, -88.071 36.677, -87....
# 42                 Texas  POLYGON ((-101.813 36.502, -100.000 36.502, -1...
# 43                  Utah  POLYGON ((-112.164 41.995, -111.047 42.001, -1...
# 44               Vermont  POLYGON ((-71.504 45.013, -71.493 44.914, -71....
# 45              Virginia  MULTIPOLYGON (((-75.398 38.013, -75.244 38.030...
# 46            Washington  MULTIPOLYGON (((-117.033 49.000, -117.044 47.7...
# 47         West Virginia  POLYGON ((-80.519 40.637, -80.519 39.722, -79....
# 48             Wisconsin  POLYGON ((-90.415 46.568, -90.229 46.508, -90....
# 49               Wyoming  POLYGON ((-109.081 45.002, -105.915 45.002, -1...
# 50           Puerto Rico  POLYGON ((-66.448 17.984, -66.771 18.006, -66....
#
#     count
# 0       6
# 1      14
# 2      34
# 3       7
# 4     284
# 5     182
# 6      11
# 7      14
# 8       9
# 9      99
# 10     47
# 11     10
# 12     28
# 13     74
# 14     31
# 15     13
# 16     26
# 17     12
# 18     15
# 19     44
# 20     43
# 21     71
# 22     94
# 23     40
# 24     21
# 25     32
# 26     15
# 27     18
# 28     18
# 29     41
# 30     37
# 31    107
# 32     61
# 33      5
# 34     56
# 35     16
# 36    156
# 37    107
# 38     12
# 39     32
# 40     11
# 41     28
# 42     90
# 43     21
# 44     28
# 45     43
# 46    151
# 47      5
# 48     77
# 49      8
# 50      3

# %%
xMap= -93.45817600000001
yMap= 39.724551999999996
print(xMap, yMap)
# Out:
# -93.45817600000001 39.724551999999996

# %%
theMap = folium.Map(location=[yMap,xMap],zoom_start=4,tiles=None)
folium.TileLayer('CartoDB positron',name='Light Map',control=False).add_to(theMap)

# %%
#creating choropleth map

m = folium.Map([yMap, xMap], zoom_start=3)

folium.Choropleth(
    geo_data=geoAndAmount,
    data=geoAndAmount,
    columns=['state', 'count'],
    fill_color='YlOrRd',
    fill_opacity=0.2, 
    line_opacity=0.8,
    legend_name='Total number of breweries per state',
    key_on='feature.properties.state',
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
style_function = lambda x: {'fillColor': '#ffffff', 
                            'color':'#000000', 
                            'fillOpacity': 0.1, 
                            'weight': 0.1}

state = folium.features.GeoJson(
    geoAndAmount,
    style_function=style_function, 
    control=False,
    tooltip=folium.features.GeoJsonTooltip(
        fields=['state',
                'count'
               ],
        aliases=['State: ',
                 'Total number of breweries: '
                 ],
        style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;") 
    )
)
m.add_child(state)
m.keep_in_front(state)
folium.LayerControl().add_to(m)

# %%
m.save('ChoroplethFirstGo.html')

# %%
m
